# %% [markdown]
# # Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff

pd.set_option('display.max_columns', None)
sns.set_palette('plasma')

# %% [markdown]
# # Importação e Visualização da base de dados

# %% [markdown]
# Importação da base de dados contendo as notas nulas em algumas linhas.

# %%
df_null = pd.read_csv('df_null.csv', sep=';', encoding='iso-8859-1')
df_null.head()
# Out:
#    NU_INSCRICAO        FAIXA ETÁRIA SEXO COR/RAÇA  \
# 0  210051567969             18 anos    M    Preta
# 1  210054292437             18 anos    M   Branca
# 2  210051340033             18 anos    F    Parda
# 3  210051891394             19 anos    F    Parda
# 4  210053720446  Entre 31 e 35 anos    F   Branca
#
#                       SITUAÇÃO DE CONCLUSÃO TIPO DE ESCOLA  \
# 0  Estou cursando e concluirei o EM em 2021        Público
# 1  Estou cursando e concluirei o EM em 2021        Público
# 2  Estou cursando e concluirei o EM em 2021        Público
# 3                           Já concluí o EM  Não respondeu
# 4                           Já concluí o EM  Não respondeu
#
#   LOCALIZAÇÃO DA ESCOLA       NO_MUNICIPIO_PROVA  TP_PRESENCA_CN  \
# 0                Urbana                  Caruaru               1
# 1            Não Consta   Brejo da Madre de Deus               0
# 2                Urbana                Salgueiro               1
# 3            Não Consta                  Caruaru               1
# 4            Não Consta  Jaboatão dos Guararapes               1
#
#    TP_PRESENCA_CH  TP_PRESENCA_LC  TP_PRESENCA_MT  NOTA_CN  NOTA_CH  NOTA_LC  \
# 0               1               1               1    554.2    524.7    456.4
# 1               1               1               0      NaN    453.8    421.4
# 2               1               1               1    410.5    498.3    459.2
# 3               1               1               1    400.9    480.8    458.0
# 4               1               1               1    552.0    595.1    541.9
#
#    NOTA_MT    IDIOMA STATUS DA REDAÇÃO  NOTA_COMP1  NOTA_COMP2  NOTA_COMP3  \
# 0    649.5    Inglês     Sem problemas       120.0       120.0       120.0
# 1      NaN    Inglês     Sem problemas        80.0       120.0        80.0
# 2    606.0  Espanhol     Sem problemas       120.0       120.0       120.0
# 3    472.0  Espanhol     Sem problemas       120.0       120.0       120.0
# 4    446.9  Espanhol     Sem problemas       120.0       120.0       120.0
#
#    NOTA_COMP4  NOTA_COMP5  NOTA_REDACAO  RENDA INTERNET  PRESENCA   NOTAS
# 0       140.0       140.0         640.0    0.5      Sim         4  2824.8
# 1       140.0       120.0         540.0    0.5      Sim         2  1415.2
# 2       120.0        20.0         500.0    1.5      Sim         4  2474.0
# 3       120.0       100.0         580.0    3.0      Sim         4  2391.7
# 4       120.0        60.0         540.0    1.5      Sim         4  2675.9

# %% [markdown]
# Importação da base de dados contendo as notas corrigidas pelo método KNN.

# %%
df_knn = pd.read_csv('df_knn.csv', sep=';', encoding='ISO-8859-1')
df_knn.head()
# Out:
#       NOTA_CN  NOTA_CH  NOTA_LC     NOTA_MT  NOTA_COMP1  NOTA_COMP2  \
# 0  554.200000    524.7    456.4  649.500000       120.0       120.0
# 1  405.269967    453.8    421.4  482.724891        80.0       120.0
# 2  410.500000    498.3    459.2  606.000000       120.0       120.0
# 3  400.900000    480.8    458.0  472.000000       120.0       120.0
# 4  552.000000    595.1    541.9  446.900000       120.0       120.0
#
#    NOTA_COMP3  NOTA_COMP4  NOTA_COMP5  NOTA_REDACAO
# 0       120.0       140.0       140.0         640.0
# 1        80.0       140.0       120.0         540.0
# 2       120.0       120.0        20.0         500.0
# 3       120.0       120.0       100.0         580.0
# 4       120.0       120.0        60.0         540.0

# %% [markdown]
# # Tratamento e Limpeza de Dados

# %% [markdown]
# Exclusão das colunas descenessárias para a análise com foco nas colunas referentes às notas com valores ausentes.

# %%
df_null.drop(columns=['NU_INSCRICAO','TP_PRESENCA_CN','TP_PRESENCA_CH','TP_PRESENCA_LC','TP_PRESENCA_MT', 'NOTA_CN', 'NOTA_CH', 'NOTA_LC', 'NOTA_MT', 'NOTA_COMP1', 'NOTA_COMP2','NOTA_COMP3', 'NOTA_COMP4', 'NOTA_COMP5', 'NOTA_REDACAO'],inplace=True)
df_null.head()
# Out:
#          FAIXA ETÁRIA SEXO COR/RAÇA                     SITUAÇÃO DE CONCLUSÃO  \
# 0             18 anos    M    Preta  Estou cursando e concluirei o EM em 2021
# 1             18 anos    M   Branca  Estou cursando e concluirei o EM em 2021
# 2             18 anos    F    Parda  Estou cursando e concluirei o EM em 2021
# 3             19 anos    F    Parda                           Já concluí o EM
# 4  Entre 31 e 35 anos    F   Branca                           Já concluí o EM
#
#   TIPO DE ESCOLA LOCALIZAÇÃO DA ESCOLA       NO_MUNICIPIO_PROVA    IDIOMA  \
# 0        Público                Urbana                  Caruaru    Inglês
# 1        Público            Não Consta   Brejo da Madre de Deus    Inglês
# 2        Público                Urbana                Salgueiro  Espanhol
# 3  Não respondeu            Não Consta                  Caruaru  Espanhol
# 4  Não respondeu            Não Consta  Jaboatão dos Guararapes  Espanhol
#
#   STATUS DA REDAÇÃO  RENDA INTERNET  PRESENCA   NOTAS
# 0     Sem problemas    0.5      Sim         4  2824.8
# 1     Sem problemas    0.5      Sim         2  1415.2
# 2     Sem problemas    1.5      Sim         4  2474.0
# 3     Sem problemas    3.0      Sim         4  2391.7
# 4     Sem problemas    1.5      Sim         4  2675.9

# %% [markdown]
# ### Concatenando as duas bases de dados:
# - Base de Dados 1 -> Referente às informações gerais dos vestibulandos
# - Base de Dados 2 -> Referente às notas dos vestibulandos

# %% [markdown]
# Juntando as notas corrigidas a base de dados com as outras informações sobre os candidatos.

# %%
df = pd.concat([df_null, df_knn], axis=1)
df.head()
# Out:
#          FAIXA ETÁRIA SEXO COR/RAÇA                     SITUAÇÃO DE CONCLUSÃO  \
# 0             18 anos    M    Preta  Estou cursando e concluirei o EM em 2021
# 1             18 anos    M   Branca  Estou cursando e concluirei o EM em 2021
# 2             18 anos    F    Parda  Estou cursando e concluirei o EM em 2021
# 3             19 anos    F    Parda                           Já concluí o EM
# 4  Entre 31 e 35 anos    F   Branca                           Já concluí o EM
#
#   TIPO DE ESCOLA LOCALIZAÇÃO DA ESCOLA       NO_MUNICIPIO_PROVA    IDIOMA  \
# 0        Público                Urbana                  Caruaru    Inglês
# 1        Público            Não Consta   Brejo da Madre de Deus    Inglês
# 2        Público                Urbana                Salgueiro  Espanhol
# 3  Não respondeu            Não Consta                  Caruaru  Espanhol
# 4  Não respondeu            Não Consta  Jaboatão dos Guararapes  Espanhol
#
#   STATUS DA REDAÇÃO  RENDA INTERNET  PRESENCA   NOTAS     NOTA_CN  NOTA_CH  \
# 0     Sem problemas    0.5      Sim         4  2824.8  554.200000    524.7
# 1     Sem problemas    0.5      Sim         2  1415.2  405.269967    453.8
# 2     Sem problemas    1.5      Sim         4  2474.0  410.500000    498.3
# 3     Sem problemas    3.0      Sim         4  2391.7  400.900000    480.8
# 4     Sem problemas    1.5      Sim         4  2675.9  552.000000    595.1
#
#    NOTA_LC     NOTA_MT  NOTA_COMP1  NOTA_COMP2  NOTA_COMP3  NOTA_COMP4  \
# 0    456.4  649.500000       120.0       120.0       120.0       140.0
# 1    421.4  482.724891        80.0       120.0        80.0       140.0
# 2    459.2  606.000000       120.0       120.0       120.0       120.0
# 3    458.0  472.000000       120.0       120.0       120.0       120.0
# 4    541.9  446.900000       120.0       120.0       120.0       120.0
#
#    NOTA_COMP5  NOTA_REDACAO
# 0       140.0         640.0
# 1       120.0         540.0
# 2        20.0         500.0
# 3       100.0         580.0
# 4        60.0         540.0

# %% [markdown]
# ### Reordenando as posições das colunas

# %% [markdown]
# Para uma melhor estruturação da base de dados.

# %%
df = df[['FAIXA ETÁRIA', 'SEXO', 'COR/RAÇA', 'SITUAÇÃO DE CONCLUSÃO', 'TIPO DE ESCOLA', 'LOCALIZAÇÃO DA ESCOLA', 'NO_MUNICIPIO_PROVA', 'IDIOMA', 'STATUS DA REDAÇÃO', 'RENDA', 'INTERNET',
       'NOTA_CN', 'NOTA_MT', 'NOTA_CH', 'NOTA_LC', 'NOTA_COMP1', 'NOTA_COMP2', 'NOTA_COMP3', 'NOTA_COMP4', 'NOTA_COMP5', 'NOTA_REDACAO', 'NOTAS', 'PRESENCA']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5038 entries, 0 to 5037
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FAIXA ETÁRIA           5038 non-null   object
#  1   SEXO                   5038 non-null   object
#  2   COR/RAÇA               5038 non-null   object
#  3   SITUAÇÃO DE CONCLUSÃO  5038 non-null   object
#  4   TIPO DE ESCOLA         5038 non-null   object
#  5   LOCALIZAÇÃO DA ESCOLA  5038 non-null   object
#  6   NO_MUNICIPIO_PROVA     5038 non-null   object
#  7   IDIOMA                 5038 non-null   object
#  8   STATUS DA REDAÇÃO      5038 non-null   object
#  9   RENDA                  5038 non-null   float64
#  10  INTERNET               5038 non-null   object
#  11  NOTA_CN                5038 non-null   float64
#  12  NOTA_MT                5038 non-null   float64
#  13  NOTA_CH                5038 non-null   float64
#  14  NOTA_LC                5038 non-null   float64
#  15  NOTA_COMP1             5038 non-null   float64
#  16  NOTA_COMP2             5038 non-null   float64
#  17  NOTA_COMP3             5038 non-null   float64
#  18  NOTA_COMP4             5038 non-null   float64
#  19  NOTA_COMP5             5038 non-null   float64
#  20  NOTA_REDACAO           5038 non-null   float64
#  21  NOTAS                  5038 non-null   float64
#  22  PRESENCA               5038 non-null   int64
# dtypes: float64(12), int64(1), object(10)
# memory usage: 905.4+ KB

# %%
# df.to_csv('df_enem.csv', sep=';', encoding='ISO-8859-1', index = False)

# %%
df2 = df.copy()

# %% [markdown]
# ### Alterando a tipagem dos dados qualitativos

# %%
df['FAIXA ETÁRIA'] = df['FAIXA ETÁRIA'].astype('category')
df['SEXO'] = df['SEXO'].astype('category')
df['COR/RAÇA'] = df['COR/RAÇA'].astype('category')
df['SITUAÇÃO DE CONCLUSÃO'] = df['SITUAÇÃO DE CONCLUSÃO'].astype('category')
df['TIPO DE ESCOLA'] = df['TIPO DE ESCOLA'].astype('category')
df['LOCALIZAÇÃO DA ESCOLA'] = df['LOCALIZAÇÃO DA ESCOLA'].astype('category')
df['NO_MUNICIPIO_PROVA'] = df['NO_MUNICIPIO_PROVA'].astype('category')
df['IDIOMA'] = df['IDIOMA'].astype('category')
df['STATUS DA REDAÇÃO'] = df['STATUS DA REDAÇÃO'].astype('category')
df['INTERNET'] = df['INTERNET'].astype('category')

# %% [markdown]
# ### Dividindo todos os valores da coluna NOTAS para termos uma média aritmética dos vestibulandos.

# %%
df.loc[:, 'NOTAS'] /= 5

# %%
df.head()
# Out:
#          FAIXA ETÁRIA SEXO COR/RAÇA                     SITUAÇÃO DE CONCLUSÃO  \
# 0             18 anos    M    Preta  Estou cursando e concluirei o EM em 2021
# 1             18 anos    M   Branca  Estou cursando e concluirei o EM em 2021
# 2             18 anos    F    Parda  Estou cursando e concluirei o EM em 2021
# 3             19 anos    F    Parda                           Já concluí o EM
# 4  Entre 31 e 35 anos    F   Branca                           Já concluí o EM
#
#   TIPO DE ESCOLA LOCALIZAÇÃO DA ESCOLA       NO_MUNICIPIO_PROVA    IDIOMA  \
# 0        Público                Urbana                  Caruaru    Inglês
# 1        Público            Não Consta   Brejo da Madre de Deus    Inglês
# 2        Público                Urbana                Salgueiro  Espanhol
# 3  Não respondeu            Não Consta                  Caruaru  Espanhol
# 4  Não respondeu            Não Consta  Jaboatão dos Guararapes  Espanhol
#
#   STATUS DA REDAÇÃO  RENDA INTERNET     NOTA_CN     NOTA_MT  NOTA_CH  NOTA_LC  \
# 0     Sem problemas    0.5      Sim  554.200000  649.500000    524.7    456.4
# 1     Sem problemas    0.5      Sim  405.269967  482.724891    453.8    421.4
# 2     Sem problemas    1.5      Sim  410.500000  606.000000    498.3    459.2
# 3     Sem problemas    3.0      Sim  400.900000  472.000000    480.8    458.0
# 4     Sem problemas    1.5      Sim  552.000000  446.900000    595.1    541.9
#
#    NOTA_COMP1  NOTA_COMP2  NOTA_COMP3  NOTA_COMP4  NOTA_COMP5  NOTA_REDACAO  \
# 0       120.0       120.0       120.0       140.0       140.0         640.0
# 1        80.0       120.0        80.0       140.0       120.0         540.0
# 2       120.0       120.0       120.0       120.0        20.0         500.0
# 3       120.0       120.0       120.0       120.0       100.0         580.0
# 4       120.0       120.0       120.0       120.0        60.0         540.0
#
#     NOTAS  PRESENCA
# 0  564.96         4
# 1  283.04         2
# 2  494.80         4
# 3  478.34         4
# 4  535.18         4

# %% [markdown]
# ### Verificação final da existência dos valores ausentes

# %%
df.isnull().sum()
# Out:
# FAIXA ETÁRIA             0
# SEXO                     0
# COR/RAÇA                 0
# SITUAÇÃO DE CONCLUSÃO    0
# TIPO DE ESCOLA           0
# LOCALIZAÇÃO DA ESCOLA    0
# NO_MUNICIPIO_PROVA       0
# IDIOMA                   0
# STATUS DA REDAÇÃO        0
# RENDA                    0
# INTERNET                 0
# NOTA_CN                  0
# NOTA_MT                  0
# NOTA_CH                  0
# NOTA_LC                  0
# NOTA_COMP1               0
# NOTA_COMP2               0
# NOTA_COMP3               0
# NOTA_COMP4               0
# NOTA_COMP5               0
# NOTA_REDACAO             0
# NOTAS                    0
# PRESENCA                 0
# dtype: int64

# %% [markdown]
# A partir desse momento, tem-se uma base de dados sem nenhuma valor ausente e pronta para ser analisada.

# %% [markdown]
# # Análise Exploratória dos Dados

# %%
df.describe()
# Out:
#              RENDA      NOTA_CN      NOTA_MT      NOTA_CH      NOTA_LC  \
# count  5038.000000  5038.000000  5038.000000  5038.000000  5038.000000
# mean      1.733823   482.295508   524.468547   508.989831   492.442692
# std       2.924758    77.230596   107.256564    96.021467    78.897466
# min       0.000000     0.000000   354.500000     0.000000     0.000000
# 25%       0.500000   424.325000   438.125000   435.700000   438.325000
# 50%       0.500000   470.650000   500.350000   506.750000   495.100000
# 75%       1.500000   531.575000   596.900000   577.675000   546.350000
# max      21.000000   778.600000   953.100000   832.500000   740.300000
#
#         NOTA_COMP1   NOTA_COMP2   NOTA_COMP3   NOTA_COMP4   NOTA_COMP5  \
# count  5038.000000  5038.000000  5038.000000  5038.000000  5038.000000
# mean    117.648698   139.869481   115.462530   128.174815   115.418596
# std      34.539284    46.483088    37.321705    39.929524    59.494668
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     100.000000   120.000000   100.000000   120.000000    80.000000
# 50%     120.000000   120.000000   120.000000   120.000000   120.000000
# 75%     140.000000   180.000000   140.000000   160.000000   160.000000
# max     200.000000   200.000000   200.000000   200.000000   200.000000
#
#        NOTA_REDACAO        NOTAS     PRESENCA
# count    5038.00000  5038.000000  5038.000000
# mean      616.57412   515.616554     3.906312
# std       193.76855   103.612505     0.431944
# min         0.00000    66.020000     2.000000
# 25%       520.00000   455.800000     4.000000
# 50%       600.00000   513.510000     4.000000
# 75%       740.00000   581.195000     4.000000
# max       980.00000   833.440000     6.000000

# %% [markdown]
# ## Análise Unidimensional
# - Objetivo: Entender como cada variável da base de dados se comporta.

# %% [markdown]
# ### FAIXA ETÁRIA

# %%
df['FAIXA ETÁRIA'].cat.categories
# Out:
# Index(['17 anos', '18 anos', '19 anos', '20 anos', '21 anos', '22 anos',
#        '23 anos', '24 anos', '25 anos', 'Entre 26 e 30 anos',
#        'Entre 31 e 35 anos', 'Entre 36 e 40 anos', 'Entre 41 e 45 anos',
#        'Entre 46 e 50 anos', 'Entre 51 e 55 anos', 'Entre 56 e 60 anos',
#        'Entre 61 e 65 anos', 'Entre 66 e 70 anos', 'Menor de 17 anos'],
#       dtype='object')

# %%
hue_order_idade = ['Menor de 17 anos','17 anos', '18 anos', '19 anos', '20 anos', '21 anos', '22 anos',
       '23 anos', '24 anos', '25 anos', 'Entre 26 e 30 anos',
       'Entre 31 e 35 anos', 'Entre 36 e 40 anos', 'Entre 41 e 45 anos',
       'Entre 46 e 50 anos', 'Entre 51 e 55 anos', 'Entre 56 e 60 anos',
       'Entre 61 e 65 anos', 'Entre 66 e 70 anos']

# %%
print(df['FAIXA ETÁRIA'].value_counts().sort_values(ascending=False).head())
print(df['FAIXA ETÁRIA'].value_counts(normalize=True).sort_values(ascending=False).head()*100)
# Out:
# 18 anos               1398
# 17 anos                998
# 19 anos                734
# 20 anos                450
# Entre 26 e 30 anos     266
# Name: FAIXA ETÁRIA, dtype: int64
# 18 anos               27.749107
# 17 anos               19.809448
# 19 anos               14.569274
# 20 anos                8.932116
# Entre 26 e 30 anos     5.279873
# Name: FAIXA ETÁRIA, dtype: float64

# %%
df['FAIXA ETÁRIA'].value_counts(normalize=True).sort_values(ascending=False).head(3).sum() * 100
# Out:
# 62.12782850337436

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.countplot(y = 'FAIXA ETÁRIA',
                   data = df,
                   order = hue_order_idade,
                   palette = 'plasma')
ax.set_title('Distribuição dos vestibulandos por faixas etárias', fontsize=22)
plt.ylabel('Faixa Etária', fontsize=20)
plt.xlabel('Quantidade', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **A faixa etária com a maior frequência dessa base de dados é a faixa etária dos 17 anos até 19 anos, representando cerca de 62,12% dos vestibulandos.**

# %% [markdown]
# ### SEXO

# %%
print(df['SEXO'].value_counts().sort_index().head())
print(df['SEXO'].value_counts(normalize=True).sort_index().head()*100)
# Out:
# F    3084
# M    1954
# Name: SEXO, dtype: int64
# F    61.214768
# M    38.785232
# Name: SEXO, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.countplot(x = 'SEXO',
                   data = df,
                   palette = 'plasma')
ax.set_title('Distribuição dos vestibulandos por sexo', fontsize=22)
plt.ylabel('Quantidade',fontsize=20)
plt.xlabel('Sexo', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# - **As mulheres representam a maioria da base de dados, totalizando cerca de 61,21%. Já os homens representam 38,78% da base de dados.**

# %% [markdown]
# ### COR/RAÇA

# %%
print(df['COR/RAÇA'].value_counts().sort_values(ascending=False).head())
print(df['COR/RAÇA'].value_counts(normalize=True).sort_values(ascending=False).head()*100)
# Out:
# Parda            2466
# Branca           1687
# Preta             580
# Não declarado     114
# Amarela           110
# Name: COR/RAÇA, dtype: int64
# Parda            48.947995
# Branca           33.485510
# Preta            11.512505
# Não declarado     2.262803
# Amarela           2.183406
# Name: COR/RAÇA, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.countplot(x = 'COR/RAÇA',
                   data = df,
                   palette = 'plasma')
ax.set_title('Distribuição dos vestibulandos por cor/raça', fontsize=22)
plt.ylabel('Quantidade',fontsize=20)
plt.xlabel('Cor/Raça', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **A cor/raça com mais frequência na base de dados foi a parda (48,94%), seguido da branca (33,48%). Os vestibulandos declarados da cor/raça preta representa 11,51%.**

# %% [markdown]
# ### SITUAÇÃO DE CONCLUSÃO

# %%
df['SITUAÇÃO DE CONCLUSÃO'].value_counts(normalize=True).sort_values(ascending=True)*100
# Out:
# Não concluí e não estou cursando o EM        0.317586
# Estou cursando e concluirei o EM em 2021    43.985709
# Já concluí o EM                             55.696705
# Name: SITUAÇÃO DE CONCLUSÃO, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.countplot(x = 'SITUAÇÃO DE CONCLUSÃO',
                   data = df,
                   palette = 'plasma')
ax.set_title('Distribuição dos vestibulandos por situação de conclusão', fontsize=22)
plt.ylabel('Quantidade',fontsize=20)
plt.xlabel('Situação de Conclusão', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **Mais da metade dos vestibulandos dentro dessa amostra de 5% da base de dados original concluíram o ensino médio (55,69%). Aproximadamente das pessoas ainda estavam cursando e concluíram o ensino médio em 2021. Além disso, menos de 1% da amostra não concluiu e nem estava cursando o ensino médio.**

# %% [markdown]
# ### TIPO DE ESCOLA

# %%
df['TIPO DE ESCOLA'].value_counts(normalize=True).sort_values(ascending=False)*100
# Out:
# Não respondeu    56.014291
# Público          36.224692
# Privada           7.761016
# Name: TIPO DE ESCOLA, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.countplot(x = 'TIPO DE ESCOLA',
                   data = df,
                   palette = 'plasma')
ax.set_title('Distribuição dos vestibulandos por tipo de escola', fontsize=22)
plt.ylabel('Quantidade',fontsize=20)
plt.xlabel('Tipo de Escola', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **Dentre as pessoas que responderam ao formulário sobre o tipo de escola que estudaram ou estavam estudando, cerca de 36,22% respoderam que são/foram da escola pública e 7,76% respoderam que são/foram da escola privada.**

# %% [markdown]
# ### INTERNET

# %%
df['INTERNET'].value_counts(normalize=True)*100
# Out:
# Sim    91.86185
# Não     8.13815
# Name: INTERNET, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.countplot(x = 'INTERNET',
                   data = df,
                   palette = 'plasma')
ax.set_title('Distribuição dos vestibulandos por acesso à internet', fontsize=22)
plt.ylabel('Quantidade',fontsize=20)
plt.xlabel('Internet', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **Diante da amostra, 91,86% dos vestibulandos responderam que possuem acesso à internet, enquanto 8,13% não tem acesso a rede de internet.**

# %% [markdown]
# ### MUNICÍPIOS

# %%
df.NO_MUNICIPIO_PROVA.value_counts().head()
# Out:
# Recife                     1186
# Petrolina                   311
# Jaboatão dos Guararapes     250
# Caruaru                     219
# Paulista                    198
# Name: NO_MUNICIPIO_PROVA, dtype: int64

# %%
df['NO_MUNICIPIO_PROVA'].value_counts(normalize=True).sort_values(ascending=False).head()*100
# Out:
# Recife                     23.541088
# Petrolina                   6.173085
# Jaboatão dos Guararapes     4.962287
# Caruaru                     4.346963
# Paulista                    3.930131
# Name: NO_MUNICIPIO_PROVA, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,25))
ax = sns.countplot(data=df, y='NO_MUNICIPIO_PROVA', palette='plasma')
ax.set_title('Distribuição dos vestibulandos por município', fontsize=22)
plt.ylabel('Municípios',fontsize=20)
plt.xlabel('Quantidade', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **Apenas a cidade do Recife representa cerca de 23,54% da amostra. Logo em seguida tem a cidade de Petrolina com 6,17% e Jaboatão dos Guararapes com 4,96%.**

# %% [markdown]
# ### IDIOMA

# %%
df['IDIOMA'].value_counts(normalize=True)*100
# Out:
# Inglês      53.25526
# Espanhol    46.74474
# Name: IDIOMA, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.countplot(x = 'IDIOMA',
                   data = df,
                   palette = 'plasma')
ax.set_title('Distribuição dos vestibulandos por idioma escolhido', fontsize=22)
plt.ylabel('Quantidade',fontsize=20)
plt.xlabel('Idioma', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **53,25% da amostra preferiram o idioma inglês para compor as questões na prova de Linguagens, enquanto 46,74% dos candidatos da amostra escolheram o espanhol.**

# %% [markdown]
# ### STATUS DA REDAÇÃO

# %%
df['STATUS DA REDAÇÃO'].value_counts(normalize=True).sort_values(ascending=False)*100
# Out:
# Sem problemas                      96.248511
# Em Branco                           1.568083
# Fuga ao tema                        1.151250
# Cópia Texto Motivador               0.337435
# Texto insuficiente                  0.238190
# Não Consta                          0.178642
# Parte desconectada                  0.138944
# Anulada                             0.099246
# Não atendimento ao tipo textual     0.039698
# Name: STATUS DA REDAÇÃO, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.countplot(y = 'STATUS DA REDAÇÃO',
                   data = df,
                   palette = 'plasma')
ax.set_title('Distribuição dos vestibulandos por status da redação', fontsize=22)
plt.xlabel('Quantidade',fontsize=20)
plt.ylabel('Status da redação', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **96,24% da amostra não tiveram problemas na prova de redação. Apenas 1,56% dos vestibulandos deixaram a redação em branco e 1,15% fugiram do tema.**

# %% [markdown]
# ### NOTAS POR ÁREA DE CONHECIMENTO

# %%
notas = df[['NOTA_CN', 'NOTA_MT', 'NOTA_CH', 'NOTA_LC', 'NOTA_REDACAO']]

# %%
notas.describe()
# Out:
#            NOTA_CN      NOTA_MT      NOTA_CH      NOTA_LC  NOTA_REDACAO
# count  5038.000000  5038.000000  5038.000000  5038.000000    5038.00000
# mean    482.295508   524.468547   508.989831   492.442692     616.57412
# std      77.230596   107.256564    96.021467    78.897466     193.76855
# min       0.000000   354.500000     0.000000     0.000000       0.00000
# 25%     424.325000   438.125000   435.700000   438.325000     520.00000
# 50%     470.650000   500.350000   506.750000   495.100000     600.00000
# 75%     531.575000   596.900000   577.675000   546.350000     740.00000
# max     778.600000   953.100000   832.500000   740.300000     980.00000

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.kdeplot(data=df[['NOTA_CN', 'NOTA_MT', 'NOTA_CH', 'NOTA_LC', 'NOTA_REDACAO']], linewidth=3, palette = 'plasma')
ax.set_title('Distribuição das notas por área de conhecimento', fontsize=22)
plt.xlabel('Notas',fontsize=20)
plt.ylabel('Densidade', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **O comportamento das notas da amostra da base de dados é muito similar quando se compara as áreas do conhecimento dos dois primeiros dias com exceção da nota de redação. Pode-se notar, por exemplo, que 50% dos vestibulandos atingiram notas parecidas em Ciência da Natureza, Matemática, Ciências Humanas e Linguagens.**

# %% [markdown]
# ## Análise Bivariada/Multivariada
# - Objetivo: Entender o comportamento de duas ou mais variáveis sendo analisadas ao mesmo tempo.

# %% [markdown]
# ### NOTAS DE CADA ÁREA POR TIPO DE ESCOLA

# %%
fig, ax = plt.subplots(figsize=(25,9))

plt.subplot(2,3,1)
ax1 = sns.boxplot(data=df,x='TIPO DE ESCOLA', y='NOTA_CN', palette = 'plasma')

plt.subplot(2,3,2)
ax2 = sns.boxplot(data=df,x='TIPO DE ESCOLA', y='NOTA_MT', palette = 'plasma')

plt.subplot(2,3,3)
ax3 = sns.boxplot(data=df,x='TIPO DE ESCOLA', y='NOTA_CH', palette = 'plasma')

plt.subplot(2,3,4)
ax4 = sns.boxplot(data=df,x='TIPO DE ESCOLA', y='NOTA_LC', palette = 'plasma')

plt.subplot(2,3,6)
ax5 = sns.boxplot(data=df,x='TIPO DE ESCOLA', y='NOTA_REDACAO', palette = 'plasma')

fig.suptitle('Distribuições das notas por tipo de escola', fontsize=24)
plt.show()

# %% [markdown]
# ### TIPO DE ESCOLA X MÉDIAS DAS NOTAS

# %%
escola_media = df.groupby('TIPO DE ESCOLA')['NOTAS'].mean().sort_values(ascending=False)
escola_media = pd.DataFrame(escola_media)
escola_media.reset_index(inplace=True)
escola_media
# Out:
#   TIPO DE ESCOLA       NOTAS
# 0        Privada  588.028491
# 1  Não respondeu  522.727597
# 2        Público  489.106729

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.barplot(data=escola_media,x='TIPO DE ESCOLA', y='NOTAS', palette = 'plasma')
ax.set_title('Distribuição das médias das notas por tipo de escola', fontsize=22)
plt.xlabel('Tipo de Escola',fontsize=20)
plt.ylabel('Médias das Notas', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **Pode-se perceber através dos boxplots que em geral a média das notas finais dos vestibulandos das escolas privadas são maiores do que os estudantes da escola pública.**

# %% [markdown]
# ### IDIOMA X NOTA DE LINGUAGENS

# %%
idioma_media_lc = df.groupby('IDIOMA')['NOTA_LC'].mean().sort_values(ascending=False)
idioma_media_lc = pd.DataFrame(idioma_media_lc)
idioma_media_lc.reset_index(inplace=True)
idioma_media_lc
# Out:
#      IDIOMA     NOTA_LC
# 0    Inglês  507.855328
# 1  Espanhol  474.883413

# %%
fig, ax = plt.subplots(figsize=(25,9))
ax = sns.barplot(data=idioma_media_lc ,x='IDIOMA', y='NOTA_LC', palette = 'plasma')
ax.set_title('Distribuição das médias das notas por tipo de escola', fontsize=22)
plt.xlabel('Idioma',fontsize=20)
plt.ylabel('Médias das Notas', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# ### RENDA X MÉDIA DAS NOTAS FINAIS

# %%
renda_media_final = df.groupby('RENDA')['NOTAS'].mean()
renda_media_final = pd.DataFrame(renda_media_final)
renda_media_final.reset_index(inplace=True)
renda_media_final
# Out:
#     RENDA       NOTAS
# 0     0.0  465.260766
# 1     0.5  484.216014
# 2     1.0  518.278875
# 3     1.5  532.420238
# 4     2.0  546.746972
# 5     2.5  553.314215
# 6     3.0  573.465682
# 7     4.0  588.687092
# 8     5.0  596.075765
# 9     6.0  607.055472
# 10    7.0  618.082791
# 11    8.0  609.904242
# 12    9.0  616.382727
# 13   10.0  607.850323
# 14   12.0  657.277143
# 15   15.0  619.076774
# 16   21.0  639.883265

# %%
clrs = ['lightgrey' if (x < max(renda_media_final['NOTAS'])) else 'purple' for x in renda_media_final['NOTAS'] ]

fig, ax = plt.subplots(figsize=(25,9))
ax = sns.barplot(data=renda_media_final , x='RENDA', y='NOTAS',
                 palette = clrs)
ax.set_title('Distribuição das médias das notas por renda', fontsize=22)
plt.ylabel('Médias das Notas',fontsize=20)
plt.xlabel('Renda (Salário Mínimo)', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);

# %% [markdown]
# > **Usou-se o salário mínimo de 2019 (R$998,00) como base nas perguntas. Percebe-se que a maior média de notas foi obtida por aqueles que tem renda de 12 salários mínimos**

# %% [markdown]
# # Perguntas - Enem 2021

# %% [markdown]
# ### 1. Qual a faixa etária que mais participou do Enem 2021?

# %%
print(df2['FAIXA ETÁRIA'].value_counts().head())
print(df2['FAIXA ETÁRIA'].value_counts(normalize=True).head()*100)
# Out:
# 18 anos               1398
# 17 anos                998
# 19 anos                734
# 20 anos                450
# Entre 26 e 30 anos     266
# Name: FAIXA ETÁRIA, dtype: int64
# 18 anos               27.749107
# 17 anos               19.809448
# 19 anos               14.569274
# 20 anos                8.932116
# Entre 26 e 30 anos     5.279873
# Name: FAIXA ETÁRIA, dtype: float64

# %%
df2['FAIXA ETÁRIA'].value_counts().sort_index().head().plot(kind='barh')
plt.show()

# %% [markdown]
# > **A faixa etária que mais participou do Enem 2021 foi a de 17-19 anos, representando cerca de 62,1% da base de dados dos vestibulandos, tendo como destaque os inscritos de 18 anos de idade atingindo 27,74% da base de dados.**

# %% [markdown]
# ### 1.1. De quais cidades esses vestibulandos com idades de 17 a 19 anos são provenientes?

# %%
df_menor20 = df2[df2['FAIXA ETÁRIA'] < '20 anos']

# %%
df_menor20.groupby('NO_MUNICIPIO_PROVA')['FAIXA ETÁRIA'].value_counts().sort_values(ascending=False).head(10)
# Out:
# NO_MUNICIPIO_PROVA       FAIXA ETÁRIA
# Recife                   18 anos         293
#                          17 anos         211
#                          19 anos         175
# Petrolina                18 anos          73
# Jaboatão dos Guararapes  18 anos          62
# Caruaru                  18 anos          58
# Jaboatão dos Guararapes  17 anos          58
# Petrolina                19 anos          56
#                          17 anos          54
# Paulista                 18 anos          48
# Name: FAIXA ETÁRIA, dtype: int64

# %%
df_menor20.groupby('NO_MUNICIPIO_PROVA')['FAIXA ETÁRIA'].value_counts().sort_values(ascending=False).head(10).plot(kind='barh')
plt.show()

# %% [markdown]
# > A grande parte dos jovens vestibulandos são da cidade do Recife.

# %% [markdown]
# ### 1.2. Qual o tipo de escola que esses vestibulandos estudam?

# %%
print(df_menor20['TIPO DE ESCOLA'].value_counts())
print(df_menor20['TIPO DE ESCOLA'].value_counts(normalize=True)*100)
# Out:
# Público          1708
# Não respondeu    1049
# Privada           373
# Name: TIPO DE ESCOLA, dtype: int64
# Público          54.568690
# Não respondeu    33.514377
# Privada          11.916933
# Name: TIPO DE ESCOLA, dtype: float64

# %%
df_menor20['TIPO DE ESCOLA'].value_counts().plot(kind='bar')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# > A maioria dos estudantes que possuem idade menor do que 20 anos e que participaram do Enem 2021, são da escola pública (54,56%). Uma quantidade considerável de estudantes não responderam ao formulário acerca do tipo de escola (33,51%) e 11,91% dos vestibulandos são de escola privada.

# %% [markdown]
# ### 2. Qual a média das notas de matemática de acordo com a cor/raça?

# %%
df2.groupby('COR/RAÇA')['NOTA_MT'].mean()
# Out:
# COR/RAÇA
# Amarela          512.720747
# Branca           552.462998
# Indígena         479.699996
# Não declarado    517.442800
# Parda            512.681701
# Preta            503.018835
# Name: NOTA_MT, dtype: float64

# %%
df2.groupby('COR/RAÇA')['NOTA_MT'].describe()
# Out:
#                 count        mean         std    min      25%         50%  \
# COR/RAÇA
# Amarela         110.0  512.720747  105.107781  368.0  433.525  481.658456
# Branca         1687.0  552.462998  116.145922  354.5  454.650  534.700000
# Indígena         81.0  479.699996   88.643686  366.3  416.400  444.500000
# Não declarado   114.0  517.442800  104.368897  357.6  442.400  479.750000
# Parda          2466.0  512.681701  100.323186  356.3  432.825  489.850000
# Preta           580.0  503.018835   94.891913  355.9  430.075  480.800000
#
#                    75%    max
# COR/RAÇA
# Amarela        595.750  840.2
# Branca         642.250  895.1
# Indígena       542.100  747.0
# Não declarado  582.075  806.4
# Parda          576.950  922.5
# Preta          566.650  953.1

# %% [markdown]
# #### Calculando o coeficiente de variação das médias das notas de matemática por cor/raça

# %%
round((df2.groupby('COR/RAÇA')['NOTA_MT'].std() / df2.groupby('COR/RAÇA')['NOTA_MT'].mean()) * 100, 2)
# Out:
# COR/RAÇA
# Amarela          20.50
# Branca           21.02
# Indígena         18.48
# Não declarado    20.17
# Parda            19.57
# Preta            18.86
# Name: NOTA_MT, dtype: float64

# %%
df2.groupby('COR/RAÇA')['NOTA_MT'].mean().plot.density()
plt.show()

# %%
mean_race = df2.groupby('COR/RAÇA')['NOTA_MT'].mean()

# %%
mean_race = pd.DataFrame(mean_race)

# %%
mean_race
# Out:
#                   NOTA_MT
# COR/RAÇA
# Amarela        512.720747
# Branca         552.462998
# Indígena       479.699996
# Não declarado  517.442800
# Parda          512.681701
# Preta          503.018835

# %%
# Teste de normalidade da distribuicao das notas de matematicas por cor/raca
stats.shapiro(df2.groupby('COR/RAÇA')['NOTA_MT'].mean())
# Out:
# ShapiroResult(statistic=0.9277167320251465, pvalue=0.5625887513160706)

# %% [markdown]
# > Através da análise gráfica e a confirmação pelo teste de normalidade de Shapiro-Wilk, pode-se dizer que as notas de matemática dos vestibulandos do Enem 2021 de acordo com a cor/raça tem uma tendência a seguir uma distribuição normal. Além disso, os coeficientes de variação indicam que não há muita heterogeneidade entre as notas baseadas na cor/raça do vestibulando.

# %% [markdown]
# ### 3. Qual a média das notas de redação de acordo com a situação de conclusão do Ensino Médio?

# %%
df2.groupby('SITUAÇÃO DE CONCLUSÃO')['NOTA_REDACAO'].mean()
# Out:
# SITUAÇÃO DE CONCLUSÃO
# Estou cursando e concluirei o EM em 2021    596.348136
# Já concluí o EM                             632.570544
# Não concluí e não estou cursando o EM       612.500000
# Name: NOTA_REDACAO, dtype: float64

# %%
df2.groupby('SITUAÇÃO DE CONCLUSÃO')['NOTA_REDACAO'].mean().plot(kind='barh')

plt.show()

# %% [markdown]
# > Pode-se observar que as médias das notas de redação entre os diferentes tipos de situação de conclusão não estão tão distintas.

# %% [markdown]
# ### 4. Qual a faixa etária mais comum nos vestibulandos que ja concluíram o Ensino Médio?

# %%
df2[df2['SITUAÇÃO DE CONCLUSÃO'] == 'Já concluí o EM'].groupby('SITUAÇÃO DE CONCLUSÃO')['FAIXA ETÁRIA'].value_counts().sort_index()
# Out:
# SITUAÇÃO DE CONCLUSÃO  FAIXA ETÁRIA
# Já concluí o EM        17 anos                49
#                        18 anos               439
#                        19 anos               560
#                        20 anos               410
#                        21 anos               255
#                        22 anos               176
#                        23 anos               121
#                        24 anos                95
#                        25 anos                82
#                        Entre 26 e 30 anos    264
#                        Entre 31 e 35 anos    116
#                        Entre 36 e 40 anos     95
#                        Entre 41 e 45 anos     61
#                        Entre 46 e 50 anos     43
#                        Entre 51 e 55 anos     20
#                        Entre 56 e 60 anos     11
#                        Entre 61 e 65 anos      4
#                        Entre 66 e 70 anos      4
#                        Menor de 17 anos        1
# Name: FAIXA ETÁRIA, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(20,9))
df2[df2['SITUAÇÃO DE CONCLUSÃO'] == 'Já concluí o EM'].groupby('SITUAÇÃO DE CONCLUSÃO')['FAIXA ETÁRIA'].value_counts().sort_index().plot(kind='barh')
plt.show()

# %%
df.columns
# Out:
# Index(['FAIXA ETÁRIA', 'SEXO', 'COR/RAÇA', 'SITUAÇÃO DE CONCLUSÃO',
#        'TIPO DE ESCOLA', 'LOCALIZAÇÃO DA ESCOLA', 'NO_MUNICIPIO_PROVA',
#        'IDIOMA', 'STATUS DA REDAÇÃO', 'RENDA', 'INTERNET', 'NOTA_CN',
#        'NOTA_MT', 'NOTA_CH', 'NOTA_LC', 'NOTA_COMP1', 'NOTA_COMP2',
#        'NOTA_COMP3', 'NOTA_COMP4', 'NOTA_COMP5', 'NOTA_REDACAO', 'NOTAS',
#        'PRESENCA'],
#       dtype='object')

# %% [markdown]
# # Testes de Hipóteses

# %% [markdown]
# ## 1) Analisar se existe alguma diferença estatística das notas finais entre os homens e mulheres da cidade do Recife

# %% [markdown]
# ### Testes de Normalidade para as notas finais por sexo na cidade do Recife:
#
# 1. H0: distribuição normal: $p > 0.05$
# 2. Ha: distribuição não-paramétrica: $p \leq 0.05$

# %%
df_recife = df.query('NO_MUNICIPIO_PROVA == "Recife"')

# %%
# Selecionando a amostra de mulheres apenas da cidade do recife
df_recife_mulheres = df.query('NO_MUNICIPIO_PROVA == "Recife" & SEXO == "F"')

# %%
# Selecionando a amostra de homens apenas da cidade do recife
df_recife_homens = df.query('NO_MUNICIPIO_PROVA == "Recife" & SEXO == "M"')

# %%
print(stats.shapiro(df_recife_mulheres.NOTAS))
print(stats.shapiro(df_recife_homens.NOTAS))
# Out:
# ShapiroResult(statistic=0.9829404354095459, pvalue=3.112968443019781e-07)
# ShapiroResult(statistic=0.9801638126373291, pvalue=3.0290675567812286e-06)

# %%
fig, ax = plt.subplots(figsize = (15, 8))
stats.probplot(df_recife_mulheres.NOTAS, dist = 'norm', plot = plt)
plt.title('Normal QQ-Plot (Mulheres)')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (15, 8))
stats.probplot(df_recife_homens.NOTAS, dist = 'norm', plot = plt)
plt.title('Normal QQ-Plot (Homens)')
plt.show()

# %% [markdown]
# ### Resultado dos testes de normalidade
#
# As notas finais tanto dos homens quanto das mulheres não passaram no teste de normalidade e por isso devemos utilizar o teste de Mann-Whitney.
#
# O teste de Mann-Whitney é utilizado para comparar se existe diferença ou não entre as medianas de duas amostras independentes não-paramétricas.

# %% [markdown]
# ### Comparação entre as medianas das notas finas entre os homens e mulheres
#
# - H0: Não há diferença entre as medianas das notas finais: $p > 0.05$
# - H1: Há diferença entre as medianas das notas finais: $p \leq 0.05$

# %%
stats.mannwhitneyu(df_recife_mulheres.NOTAS, df_recife_homens.NOTAS)
# Out:
# MannwhitneyuResult(statistic=154645.0, pvalue=0.005664181873849117)

# %%
fig, ax = plt.subplots(figsize=(15,9))
ax1 = sns.boxplot(data=df_recife,x='SEXO', y='NOTAS', palette = 'plasma')
ax.set_title('Distribuição das notas finais por sexo', fontsize=22)
plt.ylabel('Notas',fontsize=20)
plt.xlabel('Sexo', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);
plt.show()

# %% [markdown]
# ### Conclusão do teste de hipótese 1:
#
# > **De acordo com o resultado do p-valor $\rho$, a hipótese nula foi rejeitada e, portanto, há diferença entre as notas finais de acordo com o sexo dos vestibulandos na cidade do Recife.**

# %% [markdown]
# ## 2) Analisar se existe alguma diferença estatística das notas finais por cor/raça

# %% [markdown]
# ### Teste de Normalidade para as notas finais por cor/raça na cidade do Recife:
#
# 1. H0: distribuição normal: $p > 0.05$
# 2. Ha: distribuição não-paramétrica: $p \leq 0.05$

# %%
df_recife['COR/RAÇA'].unique()
# Out:
# ['Branca', 'Parda', 'Preta', 'Indígena', 'Não declarado', 'Amarela']
# Categories (6, object): ['Amarela', 'Branca', 'Indígena', 'Não declarado', 'Parda', 'Preta']

# %%
df_recife_branca = df_recife[df_recife['COR/RAÇA'] == 'Branca']
df_recife_parda = df_recife[df_recife['COR/RAÇA'] == 'Parda']
df_recife_preta = df_recife[df_recife['COR/RAÇA'] == 'Preta']
df_recife_indigena = df_recife[df_recife['COR/RAÇA'] == 'Indígena']
df_recife_nd = df_recife[df_recife['COR/RAÇA'] == 'Não declarado']
df_recife_amarela = df_recife[df_recife['COR/RAÇA'] == 'Amarela']

# %%
print('Branca -------->', stats.shapiro(df_recife_branca.NOTAS))
print('Parda --------->', stats.shapiro(df_recife_parda.NOTAS))
print('Preta --------->', stats.shapiro(df_recife_preta.NOTAS))
print('Indígena ------>', stats.shapiro(df_recife_indigena.NOTAS))
print('Não declarado ->', stats.shapiro(df_recife_nd.NOTAS))
print('Amarela ------->', stats.shapiro(df_recife_amarela.NOTAS))
# Out:
# Branca --------> ShapiroResult(statistic=0.96989905834198, pvalue=2.8779474803286575e-08)
# Parda ---------> ShapiroResult(statistic=0.9726523160934448, pvalue=3.8780754607614654e-08)
# Preta ---------> ShapiroResult(statistic=0.9769189953804016, pvalue=0.009460323490202427)
# Indígena ------> ShapiroResult(statistic=0.8121744394302368, pvalue=0.10145604610443115)
# Não declarado -> ShapiroResult(statistic=0.9627622961997986, pvalue=0.6557162404060364)
# Amarela -------> ShapiroResult(statistic=0.9624775648117065, pvalue=0.46599605679512024)

# %%
fig, ax = plt.subplots(figsize = (15, 8))
stats.probplot(df_recife_branca.NOTAS, dist = 'norm', plot = plt)
plt.title('Normal QQ-Plot (Branca)')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (15, 8))
stats.probplot(df_recife_parda.NOTAS, dist = 'norm', plot = plt)
plt.title('Normal QQ-Plot (Parda)')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (15, 8))
stats.probplot(df_recife_preta.NOTAS, dist = 'norm', plot = plt)
plt.title('Normal QQ-Plot (Preta)')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (15, 8))
stats.probplot(df_recife_indigena.NOTAS, dist = 'norm', plot = plt)
plt.title('Normal QQ-Plot (Indígena)')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (15, 8))
stats.probplot(df_recife_nd.NOTAS, dist = 'norm', plot = plt)
plt.title('Normal QQ-Plot (Não declarado)')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (15, 8))
stats.probplot(df_recife_amarela.NOTAS, dist = 'norm', plot = plt)
plt.title('Normal QQ-Plot (Amarela)')
plt.show()

# %% [markdown]
# ### Resultado dos testes de normalidade
#
# As notas finais por cor/raça que não passaram no teste de normalidade:
# - Branca
# - Parda
# - Preta
#
# e por isso devemos utilizar o teste de Kruskal-Wallis.
#
# O teste de Kruskal-Wallis, é um teste não-paramétrico e é utilizado na comparação de três ou mais amostras independentes. Ele nos indica se há diferença entre pelo menos dois deles.

# %% [markdown]
# ### Comparação entre as medianas das notas finais das cores/raças
#
# - H0: Não há diferença entre as medianas das notas finais dos grupos: $p > 0.05$
# - H1: Há diferença entre as medianas das notas finais dos grupos: $p \leq 0.05$

# %%
stats.kruskal(df_recife_branca.NOTAS,
             df_recife_parda.NOTAS,
             df_recife_preta.NOTAS,
             df_recife_indigena.NOTAS,
             df_recife_nd.NOTAS,
             df_recife_amarela.NOTAS)
# Out:
# KruskalResult(statistic=69.98997591568519, pvalue=1.0297249909605857e-13)

# %%
fig, ax = plt.subplots(figsize=(15,9))
ax = sns.boxplot(data=df_recife,x='COR/RAÇA', y='NOTAS', palette = 'plasma')
ax.set_title('Distribuição das notas finais por sexo', fontsize=22)
plt.ylabel('Notas',fontsize=20)
plt.xlabel('Cor/Raça', fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15);
plt.show()

# %% [markdown]
# ### Conclusão do teste de hipótese 2:
#
# > **De acordo com o resultado do p-valor $\rho$, a hipótese nula foi rejeitada e, portanto, há diferença entre as notas finais de acordo com a cor/raça dos vestibulandos na cidade do Recife.**
